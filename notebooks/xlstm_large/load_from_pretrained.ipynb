# %%
import sys

sys.path.append("../..")

# %%
import torch
from xlstm.xlstm_large.model import xLSTMLargeConfig, xLSTMLarge
from xlstm.xlstm_large.from_pretrained import load_from_pretrained

# %%
CHECKPOINT_PATH = "/home/gy/dl/xLSTM-7b"

# %%
model = load_from_pretrained(checkpoint_path=CHECKPOINT_PATH)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 model = load_from_pretrained(checkpoint_path=CHECKPOINT_PATH)
#
# File ~/dl/xlstm-fork/notebooks/xlstm_large/../../xlstm/xlstm_large/from_pretrained.py:48, in load_from_pretrained(checkpoint_path, return_last_states, chunkwise_kernel_name, sequence_kernel_name, step_kernel_name, backend_mode, chunk_size)
#      45         sharded_path = checkpoint_path / f"model_{n}.safetensors"
#      46 config = OmegaConf.load(checkpoint_path / "config.yaml")
# ---> 48 mlstm_config = xLSTMLargeConfig(**config)
#      49 # Note: The default weight mode is single.
#      50 # For fused weight mode convert the weights using convert_single_weights_to_fused_weights.
#      51 mlstm_config.weight_mode = "single"
#
# TypeError: xLSTMLargeConfig.__init__() got an unexpected keyword argument '_name_or_path'

# %%
model

# %%
model = model.to("cuda")
model.config.return_last_states = True

# %%
input = torch.randint(0, 2048, (2, 256)).to("cuda")
input.shape

# %%
out = model(input)

# %%
h, state = out

# %%
h.shape, len(state), type(state), len(state[0]), state[0][0].shape

# %%
list(model.state_dict().keys())
